# %% [markdown]
# # Create an Audiobook from a PDF
# ## This task tests your ability to apply Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
! pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\python312\lib\site-packages (3.0.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import the library

# %%
import PyPDF2

# %% [markdown]
# ### Extract the text

# %%
pdf_path = "C://Users//INDIRA//OneDrive//Documents//college resumeee//Resume//fastfood resume.pdf"
# Replace with your PDF file path

# Open the PDF file
with open(pdf_path, 'rb') as pdf_file:
    # Initialize PDF reader
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    # Initialize an empty string to store extracted text
    extracted_text = ""
    # Iterate through each page and extract text
    for page in pdf_reader.pages:
        extracted_text += page.extract_text()

# %% [markdown]
# ### Print the extracted text

# %%
print(extracted_text)
# Out:
#
# B INDIRA CHETTY
# 53 Winston  Park Blvd , North York, ON M 3K 1C2
# 647-321-2992  | chettybindira@gmail.com
# Objective _____________________________________________________ ______________________ __________
#                  Customer -focused and organized individual with hands -on experience in fast -paced work
# environments. Skilled in maintaining cleanliness, managing orders, and delivering excellent service.
# Enthusiastic about contributing to a team -oriented setting in the fast -food industry and ensuring a positive
# experience for customers.
# Skills _____________________________________________________ ___________________ _________________
#  Order  Preparation : Quick and accurate in preparing and packaging orders.
#  Customer  Service : Friendly and responsive to customer requests and issues.
#  Teamwork : Skilled in collaborating to ensure smooth operations.
#  Inventory : Experienced in organizing, tracking, and restocking items.
#  Health  & Safety : Maintains cleanliness and follows safety protocols.
# Education _________________________________________________ _________________ ____________
# Applied AI Solution Development                                                                                         (CURRENT )
# George brown college , Canada
# B Tech , Artificial Intelligence and Data Science                                                                  CGPA - 8.9/10
# Sri Krishna College of engineering and technology
# Experience _____________________________________________________ __________ __________ ___________
# Food Preparation Worker  (6 months )
# Chai Kings, India
#  Prepared ingredients and assisted in the preparation of popular chai beverages and snacks, ensuring
# consistency in flavor and quality.
#  Maintained a clean and organized workspace, adhering to health and safety standards.
#  Collaborated with team members to manage high order volumes efficiently during peak hours.
# Server
# Ammu Mess, India    (2 years )
#  Welcomed guests, took orders , and ensured prompt and accurate service.
#  Handled customer inquiries and resolved minor complaints to provide a positive dining experience.
#  Assisted in setting up and clearing tables, maintaining a tidy dining area.
# Additional  Information ______ _____ _______________________________ ________ _____________ __
#  Availability : Flexible for day shifts, Monday to Friday.
#  Languages : Fluent in English .

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Install the library

# %%
# !pip install pyttsx3

# %% [markdown]
# ### Import the library

# %%
import pyttsx3

# %% [markdown]
# ### Initialize a Speaker object

# %%
engine = pyttsx3.init()

# %% [markdown]
# ### Convert the text

# %%
audio_file = "output_audio.mp3"
engine.save_to_file(extracted_text, audio_file)
engine.runAndWait()

# %% [markdown]
# ### Save the audio

# %%
print(f"Audio saved as {audio_file}")
# Out:
# Audio saved as output_audio.mp3
